# %% [markdown]
# <a href="https://colab.research.google.com/github/Mathic/Myrrhage/blob/master/Lab_Fibre_Optics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Abstract
#
# We will be working with single and multimode fibres in this expirement. We have three goals for this lab (for both single and multimode fibres): calculate the numerical aperture, calculate the number of modes propagating in the fibre, find the core to cladding ratio, and measure the speed of light for 1 to 3 km of fibre.
#
# ### Numerical aperture and number of modes
#
# To measure the numerical aperture and number of modes we recorded the power for each angle of light entering the single mode (as well as the multimode, separately) fibre optic cable using logger pro *(see fig. 5, 8 and 9)*.
#
# *Table 1. Numerical Aperture (NA) and number of modes calculated for single and multimode fibres*
#
# | Cable type | Numerical Aperture | Error for NA | Number of modes (V) | Step-index modes (N) |
# |------|------|------|
# |   Single mode | 0.15 | 0.39 | 8 $\pm$ 20 | 3 $\pm$ 15 |
# |   Multimode | 0.257 | 0.082 | 78 $\pm$ 25 | (31 $\pm$ 20) $\times$ 10$^2$ |
#
# ### Core and cladding measurements and ratio
#
# The microscope (see apparatus) was used to measure the core and the cladding diameters for the single and multimode fibres *(see fig. 6)*.
#
# *Table 2. Known and average measured core and cladding diameters for single and multimode fibres (d $\equiv$ diameter)*
#
# | Cable type | Known core d ($\mu m$) | Known cladding d ($\mu m$) | Measured core d$_{avg} (\mu m$) | Measured core d$_{avg} (\mu m$) |
# |------|------|------|
# | Single mode | 8.9 | 125 | 125.764 $\pm$ 0.063 | 10.234 $\pm$ 0.063 |
# | Multimode | 62.5 | 125 | 126.460 $\pm$ 0.063 | 61.374 $\pm$ 0.063 |
#
# ### Speed of light measurements
#
# Using the oscilloscope (see aparatus), a 1km fibre optic cable and a 2km cable we measured the differences in the time it took for light to travel over 1km, 2km and 3km compared to the first detector *(see fig. 7)*.
#
# *Table 3. Time difference for each length of fibre optic cable compared to the first detector*
#
# | Cable length (m) | Cable error (m) | Time_1 ($\mu s$) | Time_2 ($\mu s$) | Time error |
# |------|------|------|------|------|------|------|
# | 4.27 | 0.30 | 19.00 | 4.40 | 0.20 |
# | 1008.28 | 0.30 | 25.50 | 7.60 | 0.20 |
# | 2009.85 | 0.30 | 29.20 | 11.20 | 0.20 |
# | 3013.86 | 0.30 | 33.60 | 16.80 | 0.20 |

# %% [markdown]
# ## Theory
#
# Fibre optic cables consist of an inner core made of glass with refractive index $n_i$ and an outer cladding, also made of glass, with refractive index $n_0$, where $n_i \gt n_0$. The cladding allows the light in the core to travel with minimum losses. We can see the diameters of the core and cladding in *fig. 1*. The core and cladding are then surrounded with shielding for durability.
#
# ![alt text](http://i67.tinypic.com/sfv4i9.png)
#
# *Figure 1. Core and cladding sizes of single and multimode cables*
#
# ![alt text](http://i64.tinypic.com/28ui3r5.png)
#
# *Figure 2. Ray of light travelling through fibre optic cable*
#
# *Figure 2* shows how light propagates through the core of the cable, which follows the condition of total internal reflection, then the angle of reflection is:
#
# $\theta_c = sin^{-1}(\frac{n_i}{n_{air}})$ (1)
#
# The angle of acceptance, $\theta_i = \theta_{max}$, where light entering at greater than $\theta_i$ is only partially reflected and the signal leaks out of the fibre. Using Snell's Law when light travels from air to the fibre:
#
# $sin\theta_i n_{air} = sin\theta_f n_i$ (2)
#
# And from geometry:
#
# $sin\theta_c = sin(90^\circ - \theta_f) = cos\theta_f = \sqrt{1 - sin^2\theta_f}$ (3)
#
# The critical angle $\theta_c$ for total internal reflection at the core/cladding interface is:
#
# $\frac{n_0}{n_i} = sin\theta_c$ (4)
#
# then,
#
# $\frac{n_0}{n_i} = \sqrt{1 - sin^2\theta_f}$ (5)
#
# rearranged:
#
# $sin\theta_i = \frac{1}{n_{air}}\sqrt{n_i^2 - n_0^2}$ (6)
#
# When the angle of acceptance is at maximum, $\theta_i = \theta_{max}$:
#
# $n_{air}sin\theta_{max} = \sqrt{n_i^2 - n_0^2}$ (7)
#
# $n_{air}sin\theta_{max}$ is known as the Numerical Aperture:
#
# $NA = \sqrt{n_i^2 - n_0^2}$ (8)
#
# Number of modes of fibre optic cable can be calculated using:
#
# $V = n_ika\sqrt{2\Delta}$ (9)
#
# where $k = \frac{2\pi}{\lambda}, \Delta = \frac{n_i^2 - n_0^2}{2n_i^2}$, and a is the radius of the core. We can rearrange the equation by substituting NA into $\Delta$ and then into V:
#
# $\Delta = \frac{NA^2}{2n_i^2}$ (10)
#
# $V = ka\sqrt{\frac{2n_i^2(NA)^2}{2n_i^2}} = ka$(NA) (11)
#
# ![alt text](http://www.fiberopticshare.com/wp-content/uploads/2016/09/single-mode-fiber-multimode-fiber-1.jpg)
#
# *Figure 3. Path of light rays through single and multimode step-index (and graded index) fibres*
#
# *Fig. 3* shows how light travels through different fibres. In multimode fibres, there are multiple different modes which have slightly different times of propagation. Only one mode propagates for a particular wavelength in a single mode fibre. The  total number of modes for step-index fibres can be calculated by:
#
# $N = \frac{1}{2}V^2$ (12)
#
# ### Speed of Light
#
# In a fibre of length L, and c is the speed of light, the total time for light to travel through the fibre is dependent on the refractive index of the ray of light in the core and cladding of the cable:
#
# $t = \frac{Ln_i / n_0}{c / n_i}$ (13)

# %% [markdown]
# ### Other calculations and errors
#
# The graphs for single and multimode calculations use Gauss' equation as a line of best fit:
#
# $Power = Ae^{\frac{-(x - B)^2}{C^2}}$ (14)
#
# In *fig. 6 and 7*, we used statistics to get the maximum value of the power and applied a %95 power drop, (0.05)(Power$_{max}$), and rearranged equation (14) to get the angle, x, at the power drop:
#
# $x = \sqrt{-C^2*ln(\frac{Power}{A})} + B$ (15)
#
# To get the error on x:
#
# $\sigma_{x} = \sqrt{(\frac{C^2}{2A\sqrt{-\ln \left(\frac{P}{A}\right)}C})^2\sigma_A^2 + \sigma_B^2 + (\frac{C\ln \left(\frac{P}{A}\right)}{\sqrt{-\ln \left(\frac{P}{A}\right)}C})^2\sigma_C^2}$ (16)
#
# x only gives the value of the angle at the drop but not how far it is from the normal. To calculate the angle of acceptance:
#
# $\theta_i = x - (\theta_{L} + \frac{\theta_{R} - \theta_{L}}{2})$ (17)
#
# with error
#
# $\sigma_{\theta_i }= \sqrt{\sigma_x^2 - \frac{1}{2}^2\sigma_{\theta_L^2} - \frac{1}{2}^2\sigma_{\theta_R^2}}$ (18)
#
# The error for the numerical aperture is:
#
# $\sigma_{NA} = \sqrt{cos^2(\theta_{max})\sigma_{\theta_{max}}^2}$ (19)
#
# For the speed of light experiment, I graphed the time vs the length of the cable and used the Least Square Method to get the line of best fit which shows a linear relationship between the time and the length of the cable:
#
# n = 4, m $\equiv $ slope, b $\equiv$ y-intercept, x = time, y = length $\Rightarrow$ y = mx + b
#
# $m = \frac{n \sum_{n=1}^{4} y_n - \sum_{n=1}^{4} x_ny_n  \sum_{n=1}^{4} x_n}{n \sum_{n=1}^{4} x_n^2 - (\sum_{n=1}^{4} x_n)^2}$ (20)
#
# $b = \frac{\sum_{n=1}^{4} x_n^2 \sum_{n=1}^{4} x_ny_n - \sum_{n=1}^{4} x_n  \sum_{n=1}^{4} x_ny_n}{n \sum_{n=1}^{4} x_n^2 - (\sum_{n=1}^{4} x_n)^2}$ (21)
#
# Finally, the error for the number of modes propagating in the fibre, and the error for the step-index calculation are:
#
# $\sigma_V = \sqrt{(-\frac{L}{t^2} \sigma_t)^2 + (\frac{1}{t}\sigma_L)^2}$ (22)
#
# $\sigma_N = V\sigma_V$ (23)

# %% [markdown]
# ## Apparatus
#
# 1.   Microscope (Carleton University Physics)
# 2.   Oscilloscope (Tektronix 3032B)
# 3.   Laser (ML810 Metrologic Neon Laser)
# 4.   Powermeter (PS3 PDL Multimeter | JDS Uniphase)
# 5.   Fibres
#   *   Single mode: Corning Optical Cable 06/05 2 SME TB2 OFNR (ETL) OFN FT4
#   *   Multimode: DEConnect Fiber Office Cable Type OFNR (UL) 62.5/125
# 6.   Fibre couplings
# 7.   Sensor for Logger Pro (LabQuest Mini | Vernier)
# 8.   Logger Pro 3.15
# 9.   Angular vernier
#
#
# ![alt text](http://i63.tinypic.com/10qa2ki.jpg)
#
# *Figure 4. Apparatus used in fibre optics experiments*

# %% [markdown]
# ## Method
#
# ![alt text](http://i66.tinypic.com/35lrchv.png)
#
# *Figure 5. Numerical aperture experiment setup for single and multimode cables*
#
# ### Numerical aperture (NA) measurements (single mode)
#
# The single mode fibre optic cable was hooked up to the power meter, attached to an angular vernier scale and aligned with the laser. It was also set up with the computer and sensor so that logger pro could record measurements of the power automatically, while we input the measurements of angle manually. *See Fig. 5*
#
# We initially turned the cable one way (clockwise or counterclockwise) using the angular vernier until logger pro was reading approximately 0W; this is the angle of total internal reflection when light is not propagating through the cable. We made the angular vernier as close to the nearest whole degree as possible so that we didn't have to worry about reading the minutes, and recorded the angle for that power in Logger Pro.
#
# We repeated this for every 1$^\circ$ turning it in the opposite of the initial direction until it read 0W to get the angle of total internal reflection at the other end. We measured the power at every 0.5$^\circ$ when we were close to the peak (90$^\circ$) to get a smoother curve. We used the two angle measurements when the power was 0W to calculate the normal. We used a gaussian fit on the graph to get the maximum power, and used a %95 power drop to get the angle of acceptance (see calculations).
#
# ### Numerical aperture (NA) measurements (multimode)
#
# The setup for multimode fibre optic cable was the same except that the equipment used was different. Instead of a single mode fibre we used a multimode fibre, and instead of an He-Ne laser we used the Solid State laser. The procedure for the multimode was the same as the single mode. We found that the angle of acceptance for the multimode fibre was larger than the angle for the single mode fibre.
#
# ### Core and cladding measurements, and ratio
#
# ![alt text](http://i68.tinypic.com/e7fh52.png)
#
# *Figure 6. Core and cladding ratio experiment setup*
#
# With the multimode fibre attached to the microscope, we focused the microscope and fiddled with the backlight to get a clear image of the outer cladding of the cable. We adjusted the light brightness from the cable to get a clear image of the core. We used the AmScope MT desktop application to take at least five measurements of the core and cladding diameters, every 800 pixels were 100$\mu m$. We repeated this with the single mode fibre optic cable.
#
# ### Speed of light measurements
#
# ![alt text](http://i64.tinypic.com/2iqczyo.png)
#
# *Figure 7. Speed of light experiment setup with 1km and 2km single mode fibre coils on the side*
#
# The setup for this experiment is seen in *fig. 7*.
#
# We compared how long it took for the light in $\mu s$ from the laser to travel through the short cable (blue) vs the different yellow cable lengths (1km, 2km, 3km), as well as the 14 ft. cable comparison, using the oscilloscope. We attached the 1km first between the 14ft cable and the x-y-z positioner, then replaced the 1km with the 2km cable, and finally measured with the 2km and the 1km together.
#
# Each cable marked the length in feet every two feet. We subtracted the smallest number in feet from one end from the largest number in feet of the other end to get the total length and converted it into metres. We used the time and length to calculate the speed of light through the fibre optic cable (see calculations).

# %% [markdown]
# ## Observations
#
# ### Numerical aperture (NA) measurements
#
# The power meter was hooked up to the computer to get the numerical value of the power at every angle in degrees that the ray of light was entering the cable. For table 4 and 5: the errors for the angle measurements are 0.5$^\prime$ or $\frac{1}{120} ^\circ$. The errors for power measurements are 0.002 mW. We used the built-in Logger Pro statistics and Gaussian Fit to get the %95 power drop and the maximum angles at the power drop for the single and multimode cables.
#
# **Single mode**
#
# *Table 4. Single mode fibre measurements for power at each angle*
#
# | Angle ($^\circ$) | Power (W) | Angle ($^\circ$) | Power (W) |
# |------|------|------|------|------|
# | 169.0 | -0.001 | 160.0 | 0.379 |
# | 168.0 | 0.009 | 159.0 | 0.293 |
# | 167.0 | 0.041 | 158.0 | 0.250 |
# | 166.0 | 0.098 | 157.0 | 0.237 |
# | 165.0 | 0.188 | 156.0 | 0.182 |
# | 164.0 | 0.248 | 155.0 | 0.108 |
# | 163.0 | 0.267 | 154.0 | 0.043 |
# | 162.0 | 0.286 | 153.0 | 0.010 |
# | 161.0 | 0.366 | 152.0 | -0.001 |
#
# ![alt text](http://i67.tinypic.com/4jqo94.png)
#
# *Fig 8. Single mode power vs angle graph*

# %% [markdown]
# **Multimode**
#
# *Table 5. Multimode fibre measurements for power at each angle*
#
# | Angle ($^\circ$) | Power (W) | Angle ($^\circ$) | Power (W) | Angle ($^\circ$) | Power (W) | Angle ($^\circ$) | Power (W) |
# |------|------|------|------|------|------|------|------|
# | 47.0 | 0.001 | 57.0 | 2.471 | 63.0 | 4.710 | 70.0 | 2.758 |
# | 48.0 | 0.067 | 58.0 | 3.030 | 64.0 | 4.747 | 71.0 | 2.250 |
# | 49.0 | 0.129 | 58.5 | 3.257 | 64.5 | 4.667 | 72.0 | 1.753 |
# | 50.0 | 0.247 | 59.0 | 3.478 | 65.0 | 4.611 | 73.0 | 1.330 |
# | 51.0 | 0.364 | 59.5 | 3.702 | 65.5 | 4.517 | 74.0 | 0.962 |
# | 52.0 | 0.564 | 60.0 | 3.916 | 66.0 | 4.399 | 75.0 | 0.652 |
# | 53.0 | 0.828 | 60.5 | 4.138 | 66.5 | 4.290 | 76.0 | 0.391 |
# | 54.0 | 1.165 | 61.0 | 4.295 | 67.0 | 4.093 | 77.0 | 0.198 |
# | 54.5 | 1.339 | 61.5 | 4.465 | 67.5 | 3.927 | 78.0 | 0.058 |
# | 55.0 | 1.570 | 62.0 | 4.542 | 68.0 | 3.707 | 79.0 | -0.003 |
# | 56.0 | 2.013 | 62.5 | 4.635 | 69.0 | 3.144 |
#
# ![alt text](http://i66.tinypic.com/2m3s51f.png)
#
# *Fig 9. Multimode power vs angle graph*

# %% [markdown]
# ### Core and cladding measurements, and ratio
#
# Using the microscope with a camera hooked up to the computer which was set up so that every 800 pixels was 100 $\mu m$, we measured the core and cladding diameters. Using the errors as a reading error of 0.5 pixel = 0.0625 => 0.063.
#
# *Table 6. Known core and cladding measurements for single and multimode fibre optic cables*
#
# |  | Cladding measurements ($\mu m$) | Core measurements ($\mu m$) |
# |------|------|------|
# | Single mode | 125 | 8.9 |
# | Multimode | 125 | 62.5 |
#
# *Table 7. Single mode cladding and core measurements*
#
# | Cladding measurements ($\mu m$) | Core measurements ($\mu m$) | Error on both ($\mu m$) |
# |------|------|
# | 125.91 | 10.20 | 0.063 |
# | 125.41 | 10.06 | 0.063 |
# | 125.71 | 10.84 | 0.063 |
# | 125.77 | 9.81 | 0.063 |
# | 126.02 | 10.26 | 0.063 |

# %% [markdown]
# ![alt text](http://i66.tinypic.com/13ykxp5.jpg)
#
# *Figure 10. Cladding diameter measurements for single mode fibre*
#
# ![alt text](http://i68.tinypic.com/122fbbr.jpg)
#
# *Figure 11. Core diameter measurements for single mode fibre*

# %% [markdown]
# *Table 8. Multimode cladding and core measurements*
#
# | Cladding measurements ($\mu m$) | Core measurements ($\mu m$) | Error on both ($\mu m$) |
# |------|------|
# | 126.60 | 61.31 | 0.063 |
# | 126.70 | 61.34 | 0.063 |
# | 126.00 | 61.41 | 0.063 |
# | 126.58 | 61.16 | 0.063 |
# | 126.42 | 61.65 | 0.063 |

# %% [markdown]
# ![alt text](http://i64.tinypic.com/hvq98y.jpg)
#
# *Figure 12. Cladding diameter measurements for multimode fibre*
#
# ![alt text](http://i68.tinypic.com/1z319gz.jpg)
#
# *Figure 13. Core diameter measurements for multimode fibre*
#
# ---

# %% [markdown]
# ### Speed of light measurements
#
# We read the value in feet of the cable at each end and subtracted the smaller number from the larger number to get the length of the cable in feet and converted into metres. The value of the time was read from the oscilloscope in $\mu s$. The observations are seen below.
#
# *Table 9. Time measurements for each cable length*
#
# | Cable length (m) | Cable error (m) | Time ($\mu s$) | Time error ($\mu s$) |
# |------|------|------|------|------|------|------|
# | 4.27 | 0.30 | 19.00 | 0.20 |
# | 1008.28 | 0.30 | 25.50 | 0.20 |
# | 2009.85 | 0.30 | 29.20 | 0.20 |
# | 3013.86 | 0.30 | 33.60 | 0.20 |
#
# I graphed the lengths of the cable vs times it took light to travel as a scatter plot then used the sum of least squares method to get a line of best fit. This shows a linear relationship between the length and time, giving the speed of light through a fibre optic cable.

# %%
from matplotlib import pyplot as plt
import math
import numpy as np
import pandas as pd

length = [4.27, 1008.28, 2009.85, 3013.86]
time = [19, 25.5, 29.2, 33.6]
m = b = 0
# sum of y, sum of x, sum of x^2, (sum of x)^2, sum of xy
sy = sx = sx2 = s2x = sxy = 0

data = []

# data.append(length)
# data.append([0.30, 0.30, 0.30, 0.30])
# data.append(time)
# data.append([0.20, 0.20, 0.20, 0.20])

# sum of least squares method
def slq():
  global m, b, sy, sx, sx2, s2x, sxy
  
  for i in range(4):
    sy += float(length[i])
    sx += float(time[i])
    sx2 += float(time[i]**2)
    sxy += float(time[i])*float(length[i])
       
  s2x = sx**2
  m = (4*sxy - sy*sx)/(4*sx2 - s2x)
  b = (sx2*sy - sx*sxy)/(4*sx2 - s2x)

slq()

# print("%f %f %f %f"% (sy, sx, sx2, sxy))
# print("%f %f"% (m, b))

# times between 19 and 34
x = np.linspace(19, 34, 100)
# apply linear equation with calculated slope and y-intercept
linear = m*x + b

# print("Table 1. Measurements of time over single mode fibre optic cable lengths")
plt.scatter(time, length)
plt.plot(x, linear,'r-')
plt.xlabel("time (μs)")
plt.ylabel("length (m)")
plt.errorbar(time, length, xerr=0.20, yerr=0.30, fmt='o', ecolor='r', capthick=2)
plt.title("\nFigure 14. Time measured for light to travel through each single mode fibre optic cable length")
plt.rcParams['figure.figsize'] = [15, 10]
# pd.DataFrame(data, columns=["1- Cable Length (m)", "2- Cable error (m)", "3- Time measurement (μs)", "4- Time error (μs)"])

# %% [markdown]
# ## Calculations
#
# ### Numerical aperture (NA) calculations
#
# Using the Gaussian fit after calculating the %95 power drop:
#
# $Power = Ae^{\frac{-(x - B)^2}{C^2}}$
#
# Rearranging to solve for the angle, x:
#
# $x = \sqrt{-C^2*ln(\frac{Power}{A})} + B$
#
# The error on x:
#
# $\sigma_{x} = \sqrt{(\frac{C^2}{2A\sqrt{-\ln \left(\frac{P}{A}\right)}C})^2\sigma_A^2 + \sigma_B^2 + (\frac{C\ln \left(\frac{P}{A}\right)}{\sqrt{-\ln \left(\frac{P}{A}\right)}C})^2\sigma_C^2}$
#
# To get the angle of acceptance at the %95 power drop:
#
# $\theta_i = x - (\theta_{L} + \frac{\theta_{R} - \theta_{L}}{2})$
#
# with error:
#
# $\sigma_{\theta_i }= \sqrt{\sigma_x^2 - \frac{1}{2}^2\sigma_{\theta_L^2} - \frac{1}{2}^2\sigma_{\theta_R^2}}$
#
# Finally, we can calculate the numerical aperture NA:
#
# $NA = n_{air}sin\theta_{max} = \sqrt{n_i^2 - n_0^2}$
#
# $\sigma_{NA} = \sqrt{cos^2(\theta_{max})\sigma_{\theta_{max}}^2}$
#
# *Table 10. Multimode and single mode fibre values to calculate for numerical aperture*
#
# | Type | %95 power drop | Angle at power drop | Angle of acceptance | Numerical aperture (NA) |
# |------|------|
# | Single mode | 18.925 mV | (168.94 $\pm$ 0.39)$^\circ$ | (8.44$\pm$ 0.39)$^\circ$ | 0.15 $\pm$ 0.39 |
# | Multimode | 4.50984 V | (77.889$\pm$ 0.085)$^\circ$ | (14.889$\pm$ 0.089)$^\circ$ | 0.257 $\pm$ 0.082 |
#
# ___
#
# **Multimode calculations**
#
# From the multimode cable Logger Pro file, the graph shows:
#
# A = 4.7902 $\pm$ 0.0194, B = 63.701 $\pm$ 0.0307, C = 8.1851 $\pm$ 0.0465.
#
# The maximum power at the maximum angle for the multimode cable was 4.7472 V $\pm$ , with %95 power drop of that being 0.05(4.7472) = 0.23736 V.
#
# Plugging the calculated power drop into the equation gives:
#
# x = $\sqrt{-(8.1851)^2*ln(\frac{4.50984}{4.7902})} + 63.701 = 77.88922683^\circ$
#
# $\sigma_{x} = \sqrt{(\frac{8.1851^2}{24.7902\sqrt{-\ln \left(\frac{0.23736}{4.7902}\right)}8.1851})^2(0.0194)^2 + (0.0307)^2 + (\frac{8.1851\ln \left(\frac{0.23736}{4.7902}\right)}{\sqrt{-\ln \left(\frac{0.23736}{4.7902}\right)}8.1851})^2(0.0465)^2} = 0.085^\circ$
#
# The midpoint angle of the multimode cable is $63^\circ$, which we subtracted from the calculated angle at the power drop to get the angle of acceptance:
#
# $\theta_i = 77.88922683 - (47 + (79 - 47)/2 )= 14.88922683^\circ$
#
# $\sigma_{\theta_i }= \sqrt{0.085^2 - \frac{1}{2}^2(1/120)^2 - \frac{1}{2}^2(1/120)^2} = 0.085^\circ$
#
# Finally the numerical aperture (NA) for the multimode cable, when $\theta_i = \theta_{max}$, where NA $= n_{air}sin(\theta_{max})$ is:
#
# $NA = (1)sin(14.88922683^\circ) = 0.257 \pm 0.082$
#
# $\sigma_{NA} = \sqrt{cos^2(14.88922683) (0.085)^2} = 0.082$
#
# ___
#
# **Single mode calculations**
#
# Using the same calculations to get the numerical aperture for single mode fibre optic cable:
#
# %95 power drop = 18.925 mV
#
# A = 355.627 $\pm$ 13.031, B = 160.526 $\pm$ 0.147, C = -4.913 $\pm$ 0.210
#
# x = 168.94$^\circ \pm$ 0.39$^\circ$
#
# $\theta_i = $ 8.44$^\circ \pm$ 0.39$^\circ$
#
# NA = 0.15 $\pm$ 0.39

# %% [markdown]
# ### Number of modes calculations
#
# From equation (11), $V = n_ika\sqrt{2\Delta}$
#
# where $\Delta = \frac{n_i^2 - n_0^2}{2n_i^2}$, $k = \frac{2\pi}{\lambda}$, $NA = \sqrt{n_i^2 - n_0^2}$, $a \equiv$ radius of fibre core. Move $n_i$ inside the square root then replace $\Delta$ and NA:
#
# $\Delta = \frac{NA^2}{2n_i^2}$
#
# $V = ka\sqrt{\frac{2n_i^2(NA)^2}{2n_i^2}} = ka(NA)$
#
# $\sigma_a = \frac{1}{2}\sigma_d$
#
# $\sigma_V = \sqrt{(k(NA)\sigma_a)^2 + (ka\sigma_{(NA)})^2}$
#
# $\lambda$ for the ML810 Metrologic Neon Laser is 632.8 nm, and the Solid State laser has wavelength of 620-690 nm.
#
# Step-index equation (12) $N = \frac{1}{2}V^2$
#
# **Single mode**
#
# a = $\frac{10.234}{2}\mu m$, NA = 0.15, k = $\frac{2\pi}{\lambda}$, $\sigma_a = \frac{1}{2}(0.0625) = 0.03125$
#
# V = ($\frac{2\pi}{632.8 nm}$)(5.117$\mu m$)(0.15) = 7.621142355
#
# $\sigma_V = \sqrt{(\frac{2\pi}{632.8 nm}(0.15)(0.03125\mu m))^2 + (\frac{2\pi}{632.8 nm}(5.117\mu m)(0.39))^2}$ = 19.81502479
#
# Step-index:
#
# N = $\frac{1}{2}(7.621142355)^2$ = 29.0409054
#
# $\sigma_N = 7.621142355(19.81502479)$ = 151.0131247
#
# **Multimode**
#
# V = ($\frac{2\pi}{632.8 nm}$)(30.687$\mu m$)(0.257) = 78.30706642
#
# $\sigma_V = \sqrt{(\frac{2\pi}{632.8 nm}(0.257)(0.03125\mu m))^2 + (\frac{2\pi}{632.8 nm}(30.687\mu m)(0.082))^2}$ = 24.98523129
#
# Step-index:
#
# N = $\frac{1}{2}(78.30706642)^2$ = 3065.998326
#
# $\sigma_N = 78.30706642(24.98523129)$ = 1956.522516

# %% [markdown]
# ### Core and cladding ratio calculations
#
# We took the average of the diameter measurements of the core as well as the cladding for both multimode and single mode fibres to use in the calculations for number of modes.
#
# $\frac{\sum_{i=1}^{n} d_i}{n}$

# %% [markdown]
# ### Speed of light calculations
#
# **Least square method to determine line of best fit**
#
# To make a the graph, the least square method was used to show a linear relationship between the amount of time light takes to travel through the cable and the length of the cable.
#
# n = 4, m $\equiv $ slope, b $\equiv$ y-intercept, x = time, y = length $\Rightarrow$ y = mx + b
#
# $m = \frac{n \sum_{n=1}^{4} y_n - \sum_{n=1}^{4} x_ny_n  \sum_{n=1}^{4} x_n}{n \sum_{n=1}^{4} x_n^2 - (\sum_{n=1}^{4} x_n)^2}$
#
# $b = \frac{\sum_{n=1}^{4} x_n^2 \sum_{n=1}^{4} x_ny_n - \sum_{n=1}^{4} x_n  \sum_{n=1}^{4} x_ny_n}{n \sum_{n=1}^{4} x_n^2 - (\sum_{n=1}^{4} x_n)^2}$
#
# **Calculating speed**
#
# We subtract the time measured for light to travel 14 ft. (4.27 m) from the time measured for 1km, 2km, and 3km.
#
# Using v = L/t, where L is the length of the cable and t is $\Delta$Time in the table gives calculated speeds of light (see table):
#
# $\sigma_v = \sqrt{(-\frac{L}{t^2} \sigma_t)^2 + (\frac{1}{t}\sigma_L)^2}$
#
# v = 1004.01 m / 6.5 $\mu s$ = 1.544630769 $\times$ 10$^{8}$ m/s
#
# $\sigma_v = \sqrt{(-\frac{1004.01 m}{(6.5 \mu s)^2} (0.2 \mu s))^2 + (\frac{1}{6.5 \mu s}(0.3 m))^2}$ = 0.047527123 $\times$ 10$^{8}$ m/s
#
# *Table 11. True cable lengths with time differences*
#
# | $\Delta$Cable length (m) | $\Delta$Time$_1 (\mu s$) | $\Delta$Time$_2 (\mu s$) | Time error ($\mu s$) | Speed of light$_1$ (m/s)| Speed of light$_2$ (m/s)|
# |------|------|------|------|------|------|------|
# | 1004.01 $\pm$ 0.30 | 6.50 | 3.20 | 0.20 | (1.545 $\pm$ 0.048) $\times$ 10$^{8}$ | (3.14 $\pm$ 0.20) $\times$ 10$^{8}$ |
# | 2005.58 $\pm$ 0.30 | 10.20 | 6.80 | 0.20 | (1.966 $\pm$ 0.039) $\times$ 10$^{8}$ | (2.949 $\pm$ 0.087) $\times$ 10$^{8}$ |
# | 3009.60 $\pm$ 0.30 | 14.60 | 12.40 | 0.20 | (2.061 $\pm$ 0.028) $\times$ 10$^{8}$ | (2.427 $\pm$ 0.039) $\times$ 10$^{8}$ |
#
# Equation (11) $t = \frac{Ln_i / n_0}{c / n_i}$ shows that the time is dependent not only on the length of the cable but the index of refraction of the core and cladding of the cable. Which means that time is also dependent on the wavelength of light propagating through the cable.
#
# $c = \lambda_0 f \equiv$ speed of light in a vacuum, $\lambda_0 = c/f$
#
# $v = \lambda f \equiv$ speed of light in a medium, $\lambda = v/f$
#
# $\frac{\lambda_0}{\lambda} =\frac{c/f}{v/f} =\frac{c}{v} = n $

# %% [markdown]
# ## Discussions
#
# The results of this experiment shows that the single mode fibre optic cable has a smaller inner core, therefore a smaller angle of acceptance, allowing less modes of propagation than the multimode cable. While the single mode cable has less modes of propagation, it allows light to travel faster and for longer distances because there are very little to no reflections inside the cable.
#
# Multimode cables are good for shorter distances and allow for more modes, or more wavelengths of light to propagate. Multimode cables start to lose more information at longer distances and are slower, but less expensive. Single mode cables are more expensive than multimode cables, but transfer information faster and are good for long distances.
#
# The reason why optic cables are better is because they have less losses than electric cables which work by transferring electrons instead of light. In the speed of light experiment, we saw that light through the fibre optic cable still travels slower than light through a vacuum. This is true because light travels slower in a medium than a vacuum, and also, in a multimode cable, light is bouncing around in the core of the cable.

# %% [markdown]
# ## References
#
# (n.d.). Retrieved February 4, 2019, from http://www.i-fiberoptics.com/laser_detail.php?id=16
#
# Corning Optical Cable 06/05 2 SME TB2 OFNR (ETL) OFN FT4 (CSA) 80' New. (n.d.). Retrieved February 4, 2019, from https://www.plcsurplussupply.com/corning-optical-cable-06-05-2-sme-tb2-ofnr-etl-ofn-ft4-csa-80-new-8244
#
# LabQuest® Mini. (n.d.). Retrieved February 4, 2019, from https://www.vernier.com/products/interfaces/lq-mini/
#
# Tektronix TDS3032B used or new for sale at used-line. (n.d.). Retrieved February 4, 2019, from https://www.used-line.com/list-oscilloscopes/digital/tektronix-tds3032b
#
# Zhang, K. (2018, May 17). Single-mode Fiber vs. Multimode Fiber: Which to Choose? Retrieved February 4, 2019, from http://www.fiberopticshare.com/single-mode-fiber-vs-multimode-fiber-choose-2.html
